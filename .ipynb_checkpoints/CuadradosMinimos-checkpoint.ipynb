# %% [markdown]
# <font color="Teal" face="Comic Sans MS,arial">
#   <h1 align="center"><i>Mínimos Cuadrados </i></h1>
#   </font>
#   <font color="Black" face="Comic Sans MS,arial">
#   <h5 align="center"><i>Profesor: M.en.C. César Carreon.</i></h5>
#     <h5 align="center"><i>Ayudante: Jesús Iván Coss Calderón.</i></h5>
#   <h5 align="center"><i>Materia: Análisis Numérico.</i></h5>
#   </font>

# %%
from mpl_toolkits import mplot3d
import random
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as la

# %%
def gen_data(n, bias, varianza):
    x = []
    y = []
    z = []
    for i in range(0, n):
        x.append(i)
        y.append((i + bias) + random.uniform(0, 1) * varianza)
        z.append((i + varianza) + random.uniform(0, 1) * bias)
        
    x=np.array(x); y=np.array(y); z=np.array(z)
    return x, y, z

# %%
for i in range(20,100,10):
    x,y,fxy = gen_data(i, 25, 50)
    A=np.zeros((len(fxy),3))
    A[:,0]=1.0
    A[:,1]=x
    A[:,2]=y
    con=la.cond(A)
    print(f"condicion {con},tamaño {len(A)},rank {la.matrix_rank(A)}")
# Out:
# condicion 249.2382003923915,tamaño 20,rank 3
# condicion 253.48484913919017,tamaño 30,rank 3
# condicion 261.19610902084975,tamaño 40,rank 3
# condicion 309.0166510338827,tamaño 50,rank 3
# condicion 340.2627534195186,tamaño 60,rank 3
# condicion 380.1881664053781,tamaño 70,rank 3
# condicion 435.25975294712345,tamaño 80,rank 3
# condicion 398.4924579476523,tamaño 90,rank 3

# %%
x,y,fxy = gen_data(100, 25, 50)


# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

# Creating plot
ax.scatter3D(x, y, fxy, color = "black")
plt.title("Data observations")

# show plot
plt.show()

# %%
class Invertion:
    ## A es un numpy array de dos dimensiones

    def __init__(self, A):
        self.A=A
    
    def Cholesky(self):
        n=self.A.shape[0]
        self.L=np.zeros_like(self.A)

        for k in range(n):
            for i in range(k+1):
                if k==i:
                    sum=0.0
                    for j in range(k):
                        sum+= self.L[k][j]*self.L[k][j]
                    self.L[k][k]=np.sqrt(self.A[k][k]-sum)

                else:
                    sum=0.0
                    for j in range(i):
                        sum+= self.L[i][j]*self.L[k][j]
                    self.L[k][i]=(self.A[k][i]-sum)/self.L[i][i]
        return self.L

# %%
class Sust:
	def __init__(self,L,U,b):
		self.L=L
		self.U=U
		self.b=b
		self.sustDelante()
		self.sustAtras()

	def sustDelante(self):
		n=len(self.L)
		self.y=np.empty_like(self.b)
		self.y[0] = self.b[0]/self.L[0][0]
		for i in range(1,n):
			self.y[i] = self.b[i]
			for j in range(0,i):
				self.y[i] -= self.L[i][j]*self.y[j]
			self.y[i] /= self.L[i][i]

	def sustAtras(self):
		n=len(self.U)
		self.x=np.empty_like(self.y)
		self.x[n-1] = self.y[n-1]/self.U[n-1][n-1]
		for i in range(n-2,-1,-1):
			self.x[i] = self.y[i]
			for j in range(i+1,n):
				self.x[i] -= self.U[i][j]*self.x[j]
			self.x[i] /= self.U[i][i]

	def get_Solve(self):
		return self.x

# %%
A=np.zeros((len(fxy),3))
A[:,0]=1.0
A[:,1]=x
A[:,2]=y

# %%
AT_A=A.T@A
AT_b=A.T@fxy

AT_A.shape
# Out:
# (3, 3)

# %%
method=Invertion(AT_A)
L=method.Cholesky()

# %%
S=Sust(L,L.T,AT_b)
alpha,beta1,beta2=S.get_Solve()

# %%
alpha,beta1,beta2
# Out:
# (65.3682967126172, 1.0466971751343168, -0.05670524301986317)

# %%
from mpl_toolkits.mplot3d import axes3d

figura = plt.figure(figsize=(14,6))
grafica = figura.add_subplot(111, projection='3d')

X,Y=np.meshgrid(x,y)
Z=beta2*Y + beta1*X +alpha

grafica.view_init(10, 70)
grafica.plot_wireframe(X,Y,Z,
                       color ='red',alpha=0.3)
grafica.scatter3D(x, y, fxy, color = "black")
